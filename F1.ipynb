# %% [markdown]
# <a href="https://colab.research.google.com/github/shuklashivansh/forage-jpmc-swe-task-1/blob/main/F1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/circuits.csv')

# %%
df.shape
# Out:
# (77, 9)

# %%
df.sample(5)
# Out:
#     circuitId    circuitRef                           name   location country  \
# 54         55         reims                    Reims-Gueux      Reims  France
# 17         18    interlagos     Autódromo José Carlos Pace  São Paulo  Brazil
# 57         58       aintree                        Aintree  Liverpool      UK
# 37         38  brands_hatch                   Brands Hatch       Kent      UK
# 47         48       mosport  Mosport International Raceway    Ontario  Canada
#
#         lat        lng  alt                                                url
# 54  49.2542   3.930830   88           http://en.wikipedia.org/wiki/Reims-Gueux
# 17 -23.7036 -46.699700  785  http://en.wikipedia.org/wiki/Aut%C3%B3dromo_Jo...
# 57  53.4769  -2.940560   20  http://en.wikipedia.org/wiki/Aintree_Motor_Rac...
# 37  51.3569   0.263056  145          http://en.wikipedia.org/wiki/Brands_Hatch
# 47  44.0481 -78.675600  332               http://en.wikipedia.org/wiki/Mosport

# %%
import seaborn as sns

# %%
sns.countplot(df['country'])
# Out:
# <Axes: xlabel='count', ylabel='country'>

# %%
import matplotlib.pyplot as plt
df['country'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>
